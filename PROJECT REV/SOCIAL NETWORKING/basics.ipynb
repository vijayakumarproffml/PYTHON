# %%
"""

network

networkx as nx inga nx yenbathu module, ithu graph draw panni mattum tha vaikum, visualize pannathu

Node---> single piece of data
Edge---> line that connects data
cluster---> group of data

G---> Graph
nx---> module
nx.Graph---> function 

# Graph create using networkX

G(object)=nx.Graph()

# create node

G.add_node("vijay")# add_node(command)
G.add_node("kumar")

# print a graph

print(G) # ipdi potal output varathu, yenendral garfe viosualize panrathuku matplot thevai so atha import pannanum

ilena atha list value ah print panni data values therijikalam
print(list(G)) ithu python list ah render aagum

# print graph of node using networkX
print(nx.node(G)) ithu run time less ah irukum so its very useful

# ovvru name ah print panna 

for i in G:
    print(i)
    
>>> vijay
    kumar

# networkX duplicte value allow pamnnathu
 same name ah iruntha atha oru name ah tha consider pannum
 
# lenth check panna

print(len(G)) v# This is the normal method to find length

print(nx.number_of_nodes(G)) # using networkx

 


"""

# %%
"""

    metplot.pyplot as plt # ithgu graph a visualize panna use aagum
    
    import networkx as nx
    import matplot.pyplot as plt
    
    G=nx.Graph()
    G.add_node("vijay")
    G.add_node("kumar")
    
    1st namma patha output list ah tha irunthathu , but inga atha visulize panna porom
    
    athuku.....
    
    nx.draw(G) # ithu simple ah grapah represent matum tha pannum, itha run panna yethume output la varathu just tick symbol matum tha kaatum
    
    atha visualize pannaum na athu ku tha matplot use panrum
    
    plt.show()
    
    -----------------------------------------------------------------------------------------------------------------------------------------------------------------------
    G=nx.Graph()
    G.add_node("vijay")
    G.add_node("kumar")
    
    G2=nx.Graph()
    G.add_node("karthi")
    G.add_node("keyan")
    
    nx.draw(G)
    nx.draw(G2)
    plt.show()
    
    ipo itha run panna ore graph la intha 2 graph aum visulaize pannum athu paaka nalla irukathu so atha differencuate panni 
    katna nalla irukum, athuku nx.draw(G2,node_color='red')# inga argument pass panrom differenciate panrathuku
    
    athuve yenaku intha rendu graph ah um thani thaiya visulize pannanum na, athuku
    nx.draw(G)
    plt.show()
    
    nx.draw(G2)
    plt.show() inga yenna na first visual aagura graph apdiye iruku, yepo current graph visual ah close panromo apo tha next visual ku pogum
    
    # ipo rendu graph or data set ah same time la visualize pannanum na
    nx.figure(1)
    nx.draw(G)
    
    nx.figure(2)
    nx.draw(G2)
    plt.show()
    # inga ist graph ku figure create panni atha show pannu then next figure 2 ku po nu solra mari,
    1st graph plt.show() nu kudutha run aagurathu stop aagirum next code ku pogathu
    
    
    
    
    -----------------------------------------------------------------------------------------------------------------------------------------------------------------------
    

"""

# %%
"""
  # create Edges
    import networkx as nx
    import matplot.pyplot as plt
    
    G=nx.Graph()
    G.add_node("vijay")
    G.add_node("kumar")
    G.add_node("karthi")
    G.add_node("keyan")
    
    # add edge
    G.add_edge("vijay","kumar")
    G.add_edge("karthi","keyan")
    
    
    # add muliple edge on tuple
    tuple la multiple values store pannalam
    
    G.add_edges_from([("vijay","kumar"),("karthi","keyan")])
    
    nx.draw(G)
    plt.show()
    
-----------------------------------------------------------------------------------------------------------------------------------------------------------------------
     
    #  Edges create panrathu moolama node create pannalam, (add_nodes ilama)
    
    G.Graph()
    G.add_edges_from([("vijay","kumar"),("karthi","keyan")])
    
     nx.draw(G)
    plt.show()
    
-----------------------------------------------------------------------------------------------------------------------------------------------------------------------

    # Edges ah oru variable name la assign panni atha argument ah pass pannalam
    
    names=[("vijay","kumar"),("karthi","keyan")]
    
    G.Graph()
    G.add_edges_from(names)
    
     nx.draw(G)
    plt.show()

-----------------------------------------------------------------------------------------------------------------------------------------------------------------------

  # Remove Edges 
  
  names=[("vijay","kumar"),("karthi","keyan")]
    
    G.Graph()
    G.add_edges_from(names)
    
    g.remove_edge("karthi","keyan")
    
    # clear all
    G.clear()
    
    print(nx.number_of_edges(G)) # it shows that how many edges are in tha graph
    
    nx.draw(G)
    plt.show()
    
    # yena method pannalum visualization ku munnadi pananum , apdi pannalena graph visualization correct ah varathu

     

"""

# %%
"""
  # add labels
    
    names=[("vijay","kumar"),("karthi","keyan")]
    
    G.Graph()
    G.add_edges_from(names)
    
    # change node shape ---> bbox=dict() ithu already iruntha round shape node ku mela just shape ah mathum, aanalum antha round shape node irukum
    # change node shape tranprancy ---> bbox=dict(alpha=.5)
    # change node color ---> bbox=dict(facecolor="yellow")
    # 1st create paana node color marama still apdiye irukku .... athaium change panna mudium
    # change font---> font_family='font oda name kudukanum inga'
    
    nx.draw(G,with_labels=True,font_size=20,font_color='rose',etc.....)
    plt.show()

"""

# %%
"""
  outside la iruka EXEL , XML,JPEG file ah accsess parara mathod
  
  import networkx as nx 
  import matplot.pyplot as plt
  import xml.etree.ElementTree as ET
  
  file="inga antha file oda location and name "
  
  G=nx.Graph()
  names=[]
  
  tree=ET.parse(file)
  Root=tree.getroot()
  
  #xml file ah accsesss panni iter panrom
  
  for item in Root.iter("relationship"):
         person1=item.attrib("person1")
         person2=item.attrib("person2")
         names.append(person1,person2)
         
         
  G.add_edges_from(names)
  
  nx.draw(G,with_labels=True)
  plt.show
         

"""

# %%
'''
  
  for loop in networkx
  
  # 2 different list la iruka data ku edges create panra method
  
  import networkx as nx
  import matplot.pyplot as plt
  
  name1=['vijay','kumar']  #data sets
  name2=['karthi','keyan'] # data sets
  
  G=nx.Graph()
  
  # first ithuku edges create pannanum na first 2 udaya length um equal ah irukanum
  
if len(name1)==len(name2):
            for i in range(len(name1)):
                 G.add_edge(name1[i],name2[i])
                 
nx.draw(G,with_labels=True)
plt.show
  

'''

# %%
'''
  # node udaya color change panrom
  
  import networkx as nx 
  import matplot.pyplot as plt
  import xml.etree.ElementTree as ET
  
  file="inga antha file oda location and name "
  
  G=nx.Graph()
  names=[]
  
  tree=ET.parse(file)
  Root=tree.getroot()
  
  #xml file ah accsesss panni iter panrom
  
  for item in Root.iter("relationship"):
         person1=item.attrib("person1")
         person2=item.attrib("person2")
         gender1=item.attrib("gender1")
         gender2=item.attrib("gender2")
         
         # relationship la yellathaum graph la poda porom
         G.add_node(person1,gender="gender1")
         G.add_node(person2,gender="gender2")
         
         names.append(person1,person2)
         
  # gender ku yethamari color change panna porom
  color_map=nx.get_node_attributes("gender") # ithku vara output dictionary format la tha varum ,keys=name values=gender
  >>> {'vijay':'male'}
  
  for key in color_map:
      # print(key) # keys
      # print(color_map[key]) # values
      if color_map[key]=='male':
           color_map[key]="blue"
      
      if color_map[key]=='female':
           color_map[key]="rose"
      >>> {'vijay':"blue"}
      
    # mela color change panrathukana codition potachu , than atha color ah mathanum
    gender_color=[color_map.get(node) for node in G.nodes]
  
  G.add_edges_from(names)
  
  nx.draw(G,with_labels=True, node_color=gender_color)
  plt.show
  


'''

# %%
# node size change panrathuku, yearuku athiga connection iruko avangaluku matha node ah vida size athigama irukum


import networkx as nx
import matplotlib.pyplot as plt
import xml.etree.ElementTree as ET

file = "D:/PYTHON/PROJECT REV/SOCIAL NETWORKING/realationship.xml"

G = nx.Graph()
names = []
total_names=[]


Tree = ET.parse(file)
Root = Tree.getroot()

for item in Root.iter("relationship"):
    person1 = item.attrib["person1"]
    person2 = item.attrib["person2"]
    gender1 = item.attrib["gender1"]
    gender2 = item.attrib["gender2"]

    G.add_node(person1, gender=gender1)
    G.add_node(person2, gender=gender2)
    total_names.append(person1)
    total_names.append(person2)
    

    names.append((person1, person2))

color_map = nx.get_node_attributes(G, "gender")

for key in color_map:
    if color_map[key] == "male":
        color_map[key] = 'blue'

    if color_map[key] == "female":
        color_map[key] = "pink"

gender_color = [color_map.get(node) for node in G.nodes()]
node_sizes=[(total_names.count(node)*500) for node in G.nodes()]


G.add_edges_from(names)


pos = nx.spring_layout(G)  # Position nodes using Fruchterman-Reingold force-directed algorithm
plt.figure(figsize=(10, 6))  # Adjust figure size if needed
nx.draw(G, pos, with_labels=True, node_color=gender_color,node_size=node_sizes)
plt.show()

# %%
# shortest path

# %%
import time
import queue
import networkx as nx
import matplotlib.pyplot as plt
import xml.etree.ElementTree as ET
file = "D:/PYTHON/PROJECT REV/SOCIAL NETWORKING/realationship.xml"

G = nx.Graph()
names = []

Tree = ET.parse(file)
Root = Tree.getroot()

for item in Root.iter("relationship"):
    person1 = item.attrib["person1"]
    person2 = item.attrib["person2"]
    gender1 = item.attrib["gender1"]
    gender2 = item.attrib["gender2"]

    G.add_node(person1, gender=gender1)
    G.add_node(person2, gender=gender2)

    names.append((person1, person2))

color_map = nx.get_node_attributes(G, "gender")

for key in color_map:
    if color_map[key] == "male":
        color_map[key] = 'blue'

    if color_map[key] == "female":
        color_map[key] = "pink"

gender_color = [color_map.get(node) for node in G.nodes()]

G.add_edges_from(names)
pos = nx.spring_layout(G)  # Position nodes using Fruchterman-Reingold force-directed algorithm
plt.figure(figsize=(10, 6))  # Adjust figure size if needed
nx.draw(G, pos, with_labels=True, node_color=gender_color, node_size=500)
plt.title('SOCIAL NETWORK')
plt.pause(1)
plt.show()



def order_bfs(graph,start_node):
    visited=set()
    order=[]
    q=queue.Queue()
    q.put(start_node)
    
    while not q.empty():
        vertex=q.get()
        if vertex not in visited:
            visited.add(vertex)
            order.append(vertex)
            for node in graph[vertex]:
                if node not in visited:
                    q.put(node)
    return order


def order_dfs(graph,start_node,visited=None):
    if visited is None:
        visited=set()
    order=[]
    
    if start_node not in visited:
        visited.add(start_node)
        order.append(start_node)
        for node in graph[start_node]:
            if node not in visited:
                order.extend(order_dfs(G,node,visited))
                
    return order

def visualization(order,title,G,pos):
    plt.figure()
    plt.title(title)
    for i, node in enumerate(order,start=1):
        plt.clf()
        plt.draw
    
    nx.draw(G,pos,with_labels=True,node_color=['r' if n==node else 'blue' for n in G.nodes()])
    plt.show()
    time.sleep(0.5)
    
    pos=nx.spring_layout(G)
    
    visualization(order_bfs(G,"vijay"),"BFS VISUALIZATION",G,pos)
    visualization(order_dfs(G,"vijay"),"DFS VISUALIZATION",G,pos)
