# %%
'''

TEXT  ah thavila vulla yellame binary tha
pictures
videos
audios

'''

# %%
n=open("c:/Users/ELCOT/Downloads/jiraya&naruto.jpg","r")

for i in n:
    print(i) # inga read mode la binary work aagathu,so rb(read binary use pannanum)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[2], line 3
#       1 n=open("c:/Users/ELCOT/Downloads/jiraya&naruto.jpg","r")
# ----> 3 for i in n:
#       4     print(i)
#
# File c:\Program Files\Python311\Lib\encodings\cp1252.py:23, in IncrementalDecoder.decode(self, input, final)
#      22 def decode(self, input, final=False):
# ---> 23     return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x90 in position 531: character maps to <undefined>

# %%
n=open("c:/Users/ELCOT/Downloads/jiraya&naruto.jpg","rb")

for i in n:
    print(i) # inga read mode la binary work aagathu,so rb(read binary use pannanum) kela irukura yellame pixels
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x00H\x00H\x00\x00\xff\xe1\x00tExif\x00\x00MM\x00*\x00\x00\x00\x08\x00\x05\x01\x1a\x00\x05\x00\x00\x00\x01\x00\x00\x00J\x01\x1b\x00\x05\x00\x00\x00\x01\x00\x00\x00R\x01(\x00\x03\x00\x00\x00\x01\x00\x02\x00\x00\x02\x13\x00\x03\x00\x00\x00\x01\x00\x01\x00\x00\xc6\xfe\x00\x02\x00\x00\x00\x11\x00\x00\x00Z\x00\x00\x00\x00\x00\x00\x00H\x00\x00\x00\x01\x00\x00\x00H\x00\x00\x00\x01Google Inc. 2016\x00\x00\xff\xe2\x02(ICC_PROFILE\x00\x01\x01\x00\x00\x02\x18\x00\x00\x00\x00\x02\x10\x00\x00mntrRGB XYZ \x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00acsp\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01\x00\x00\xf6\xd6\x00\x01\x00\x00\x00\x00\xd3-\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\tdesc\x00\x00\x00\xf0\x00\x00\x00trXYZ\x00
# ...

# %%
# intha image inoru file ku copy panra method

# %%
n=open("c:/Users/ELCOT/Downloads/jiraya&naruto.jpg","rb")
n1=open("newpic.jpg","wb")

for i in n:
    n1.write(i)

# %%
'''n=open("c:/Users/ELCOT/Downloads/jiraya&naruto.jpg","rb")
n1=open("newpic.jpg","wb")
n1.write(i)
# ipdi panna new image copy aagala'''
# Out:
# 'n=open("c:/Users/ELCOT/Downloads/jiraya&naruto.jpg","rb")\nn1=open("newpic.jpg","wb")\nn1.write(i)\n# ipdi panna new image copy aagala'
